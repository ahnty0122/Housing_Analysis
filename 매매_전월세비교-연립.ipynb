# %% [markdown]
# ## 주택거래 매매, 전월세 데이터 merge
# ##### 같은 연립에 대해 매매와 전월세 거래가 어떤 차이가 있는지 확인

# %%
import pandas as pd

# %%
# 주택거래_매매 데이터 불러오기
df1 = pd.read_csv('./data/주택거래_매매.csv')
df1
# Out:
#          계약년월  계약일              지역명   본번   부번                단지명   전용면적(㎡)  \
# 0      201701    1      세종특별자치시 보람동  743  0.0             스타힐타워Ⅰ   16.9849
# 1      201703   13      세종특별자치시 보람동  713  0.0  호려울마을10단지(중흥S클래스)  109.9692
# 2      201703   16      세종특별자치시 보람동  743  0.0             스타힐타워Ⅰ   16.6229
# 3      201704    1      세종특별자치시 보람동  743  0.0             스타힐타워Ⅰ   21.6349
# 4      201704   20      세종특별자치시 보람동  713  0.0  호려울마을10단지(중흥S클래스)   98.0608
# ...       ...  ...              ...  ...  ...                ...       ...
# 25702  202007    1  세종특별자치시 부강면 산수리  NaN  NaN                NaN       NaN
# 25703  202007    3  세종특별자치시 금남면 남곡리  NaN  NaN                NaN       NaN
# 25704  202011    3  세종특별자치시 전동면 미곡리  NaN  NaN                NaN       NaN
# 25705  202012   29  세종특별자치시 전동면 미곡리  NaN  NaN                NaN       NaN
# 25706  202011   28  세종특별자치시 전동면 석곡리  NaN  NaN                NaN       NaN
#
# ...

# %%
# 주택거래_전월세 데이터 불러오기
df2 = pd.read_csv('./data/주택거래_전월세.csv', low_memory=False)
df2
# Out:
#          계약년월  계약일              지역명    본번   부번                  단지명 전월세구분  \
# 0      201701   13      세종특별자치시 고운동  1396  0.0  가락마을 20단지(호반베르디움5차)    전세
# 1      201701   14      세종특별자치시 고운동  1396  0.0  가락마을 20단지(호반베르디움5차)    전세
# 2      201701   14      세종특별자치시 고운동  1396  0.0  가락마을 20단지(호반베르디움5차)    전세
# 3      201701   15      세종특별자치시 고운동  1396  0.0  가락마을 20단지(호반베르디움5차)    전세
# 4      201702    4      세종특별자치시 고운동  1396  0.0  가락마을 20단지(호반베르디움5차)    월세
# ...       ...  ...              ...   ...  ...                  ...   ...
# 45192  202004    3  세종특별자치시 연서면 부동리   NaN  NaN                  NaN    월세
# 45193  202010   23  세종특별자치시 장군면 송학리   NaN  NaN                  NaN    월세
# 45194  202010   31  세종특별자치시 장군면 송학리   NaN  NaN                  NaN    전세
# 45195  202008    7  세종특별자치시 전의면 달전리   NaN  NaN                  NaN    월세
# 45196  202010   22  세종특별자치시 전의면 신정리   NaN  NaN                  NaN    전세
#
#        전용면적(㎡) 보증금(만원)  월세(만원)  ...    건축년도  TYPE  건물명   도로조건 계약면적(㎡)  \
# ...

# %%
df1['TYPE'].unique()
# Out:
# array(['아파트', '연립', '단독', '오피스텔'], dtype=object)

# %%
# 데이터들 열 확인
print(df1.columns)
print(df2.columns)
# Out:
# Index(['계약년월', '계약일', '지역명', '본번', '부번', '단지명', '전용면적(㎡)', '거래금액(만원)', '층',
#        '건축년도', '해제사유발생일', 'TYPE', '건물명', '대지권면적(㎡)', '주택유형', '도로조건', '연면적(㎡)',
#        '대지면적(㎡)', '행정동코드', '시군구', '읍면동명', '지역코드', '동리명'],
#       dtype='object')
# Index(['계약년월', '계약일', '지역명', '본번', '부번', '단지명', '전월세구분', '전용면적(㎡)', '보증금(만원)',
#        '월세(만원)', '층', '건축년도', 'TYPE', '건물명', '도로조건', '계약면적(㎡)', '행정동코드', '시군구',
#        '읍면동명', '지역코드', '동리명'],
#       dtype='object')

# %%
# 아파트 매매, 전월세 데이터만 불러오기
df1_apart = df1[df1['TYPE']=='연립']
df1_apart
# Out:
#          계약년월  계약일              지역명   본번   부번  단지명  전용면적(㎡) 거래금액(만원)    층  \
# 755    201801   26      세종특별자치시 보람동  744  0.0  NaN  24.4267    9,090  8.0
# 756    201912   17      세종특별자치시 보람동  744  0.0  NaN  21.6349   10,300  7.0
# 757    202001   30      세종특별자치시 보람동  743  0.0  NaN  16.6229    7,600  8.0
# 758    202002   26      세종특별자치시 보람동  744  0.0  NaN  26.5949    9,000  6.0
# 759    202003   13      세종특별자치시 보람동  744  0.0  NaN  21.6349    8,500  6.0
# ...       ...  ...              ...  ...  ...  ...      ...      ...  ...
# 25253  201906   14  세종특별자치시 부강면 문곡리  669  7.0  NaN  72.8000   18,350  4.0
# 25254  201906   14  세종특별자치시 부강면 문곡리  669  7.0  NaN  72.8000   18,350  3.0
# 25255  201906   14  세종특별자치시 부강면 문곡리  669  7.0  NaN  72.3300   17,632  2.0
# 25265  202002   19  세종특별자치시 소정면 대곡리  457  6.0  NaN  74.9200    5,650  1.0
# 25266  202010   16  세종특별자치시 소정면 대곡리  467  0.0  NaN  53.3400    3,400  2.0
#
#          건축년도  ...  대지권면적(㎡) 주택유형 도로조건  연면적(㎡) 대지면적(㎡)       행정동코드      시군구  \
# ...

# %%
# 건물 전세 데이터 불러오기
df2_apart = df2[(df2['TYPE']=='연립') & (df2['전월세구분']=='전세')]
df2_apart
# Out:
#          계약년월  계약일              지역명   본번    부번  단지명 전월세구분  전용면적(㎡) 보증금(만원)  \
# 5933   201709   27  세종특별자치시 금남면 용포리  148   4.0  NaN    전세   57.240   4,000
# 5934   201806   22  세종특별자치시 금남면 용포리  107   0.0  NaN    전세   59.200   4,500
# 5937   201911   15  세종특별자치시 금남면 용포리  107   0.0  NaN    전세   59.200   2,500
# 5938   202009   20  세종특별자치시 금남면 용포리   53   2.0  NaN    전세   65.400   4,000
# 16204  201707   26      세종특별자치시 도담동  674   0.0  NaN    전세   22.686   8,500
# ...       ...  ...              ...  ...   ...  ...   ...      ...     ...
# 44036  201812    2  세종특별자치시 장군면 도계리    6   5.0  NaN    전세   83.890   4,000
# 44215  201909   23  세종특별자치시 연기면 보통리  340   8.0  NaN    전세   48.600   3,000
# 44216  201906   20  세종특별자치시 연기면 보통리  340  11.0  NaN    전세   58.770   2,500
# 44355  201910   18  세종특별자치시 전의면 관정리  262   4.0  NaN    전세   53.965   3,000
# 44358  202009    3  세종특별자치시 전의면 관정리  259   3.0  NaN    전세   56.460   4,000
#
# ...

# %%
# 같은 값 가지는 데이터를 기준으로 데이터 합쳐 같은 건물에 대한 매매, 전월세 데이터 비교 (연립)
merge_df = pd.merge(df1_apart, df2_apart, how = 'inner', on = ['지역명', '본번', '부번', '단지명', '전용면적(㎡)', '건축년도', 'TYPE', '건물명', '도로조건', '행정동코드', '시군구', '읍면동명', '지역코드', '동리명'])
merge_df
# Out:
#      계약년월_x  계약일_x               지역명   본번   부번  단지명  전용면적(㎡) 거래금액(만원)  층_x  \
# 0    201912     17       세종특별자치시 보람동  744  0.0  NaN  21.6349   10,300  7.0
# 1    201912     17       세종특별자치시 보람동  744  0.0  NaN  21.6349   10,300  7.0
# 2    202003     13       세종특별자치시 보람동  744  0.0  NaN  21.6349    8,500  6.0
# 3    202003     13       세종특별자치시 보람동  744  0.0  NaN  21.6349    8,500  6.0
# 4    202006     25       세종특별자치시 보람동  744  0.0  NaN  21.6349    8,900  5.0
# ..      ...    ...               ...  ...  ...  ...      ...      ...  ...
# 785  201910     28  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    5,900  2.0
# 786  201910     28  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    5,900  2.0
# 787  201910     28  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    5,900  2.0
# 788  202009      4  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    7,900  2.0
# 789  202009      4  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    7,900  2.0
#
# ...

# %%
# 합쳐진 데이터의 열 목록 확인
merge_df.columns
# Out:
# Index(['계약년월_x', '계약일_x', '지역명', '본번', '부번', '단지명', '전용면적(㎡)', '거래금액(만원)',
#        '층_x', '건축년도', '해제사유발생일', 'TYPE', '건물명', '대지권면적(㎡)', '주택유형', '도로조건',
#        '연면적(㎡)', '대지면적(㎡)', '행정동코드', '시군구', '읍면동명', '지역코드', '동리명', '계약년월_y',
#        '계약일_y', '전월세구분', '보증금(만원)', '월세(만원)', '층_y', '계약면적(㎡)'],
#       dtype='object')

# %%
# 합쳐진 데이터에서 필요없는 열 제거 (연립의 경우 )
del merge_df['대지권면적(㎡)'], merge_df['연면적(㎡)'], merge_df['해제사유발생일'], merge_df['도로조건'], merge_df['계약면적(㎡)'], merge_df['대지면적(㎡)']
merge_df
# Out:
#      계약년월_x  계약일_x               지역명   본번   부번  단지명  전용면적(㎡) 거래금액(만원)  층_x  \
# 0    201912     17       세종특별자치시 보람동  744  0.0  NaN  21.6349   10,300  7.0
# 1    201912     17       세종특별자치시 보람동  744  0.0  NaN  21.6349   10,300  7.0
# 2    202003     13       세종특별자치시 보람동  744  0.0  NaN  21.6349    8,500  6.0
# 3    202003     13       세종특별자치시 보람동  744  0.0  NaN  21.6349    8,500  6.0
# 4    202006     25       세종특별자치시 보람동  744  0.0  NaN  21.6349    8,900  5.0
# ..      ...    ...               ...  ...  ...  ...      ...      ...  ...
# 785  201910     28  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    5,900  2.0
# 786  201910     28  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    5,900  2.0
# 787  201910     28  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    5,900  2.0
# 788  202009      4  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    7,900  2.0
# 789  202009      4  세종특별자치시 조치원읍 봉산리  190  7.0  NaN  50.4200    7,900  2.0
#
# ...

# %%
# 열 목록 다시 확인
merge_df.columns
# Out:
# Index(['계약년월_x', '계약일_x', '지역명', '본번', '부번', '단지명', '전용면적(㎡)', '거래금액(만원)',
#        '층_x', '건축년도', 'TYPE', '건물명', '주택유형', '행정동코드', '시군구', '읍면동명', '지역코드',
#        '동리명', '계약년월_y', '계약일_y', '전월세구분', '보증금(만원)', '월세(만원)', '층_y'],
#       dtype='object')

# %%
merge_df.to_csv('./data/매매_전월세_비교_연립.csv', index = False, encoding = 'utf-8')
