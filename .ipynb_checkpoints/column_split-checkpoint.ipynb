# %% [markdown]
# ### 3번 파일 시군구(지역명) 열을 시군구, 동리, 읍면동으로 열 분리

# %%
import pandas as pd

# %%
df = pd.read_csv('3.세종시_아파트(매매)_실거래가.csv', encoding = 'cp949')
df
# Out:
#          계약년월  계약일               시군구    본번  부번                단지명   전용면적(㎡)  \
# 0      201701    1       세종특별자치시 보람동   628   2       스타힐타워Ⅰ(C2-3)   16.9849
# 1      201701    1       세종특별자치시 종촌동   683   0  가재마을2단지(호반베르디움3차)   59.8652
# 2      201701    2       세종특별자치시 고운동  1393   0    가락마을15단지(중흥파크뷰)   84.9894
# 3      201701    2       세종특별자치시 고운동  1706   0    가락마을8단지(고운뜰아파트)   84.9800
# 4      201701    2       세종특별자치시 아름동  1284   0    범지기마을7단지 호반에코시티   84.9280
# ...       ...  ...               ...   ...  ..                ...       ...
# 21135  202010   27  세종특별자치시 조치원읍 신흥리   399   0    조치원 신흥 e편한세상(아)  176.3430
# 21136  202010   27  세종특별자치시 조치원읍 침산리    89   0              욱일아파트   84.9900
# 21137  202010   28       세종특별자치시 도담동   639   0    도램마을17단지(모아미래도)   84.9690
# 21138  202010   28   세종특별자치시 부강면 부강리   401  48                 주연   59.8200
# 21139  202010   28  세종특별자치시 조치원읍 죽림리   396   0            조치원죽림자이   84.6641
#
#        거래금액(만원)   층  건축년도
# 0          8600   7  2016
# 1         27300   7  2014
# 2         32000   3  2015
# 3         30500  20  2015
# 4         31300   6  2014
# ...         ...  ..   ...
# 21135     50000  10  2008
# 21136     23500  20  1996
# 21137     68000   9  2015
# 21138      6500  11  1992
# 21139     37000   6  2008
#
# [21140 rows x 10 columns]

# %%
df.columns = ['계약년월', '계약일', '지역명', '본번', '부번', '단지명', '전용면적(㎡)', '거래금액(만원)', '층',
       '건축년도']
df
# Out:
#          계약년월  계약일               지역명    본번  부번                단지명   전용면적(㎡)  \
# 0      201701    1       세종특별자치시 보람동   628   2       스타힐타워Ⅰ(C2-3)   16.9849
# 1      201701    1       세종특별자치시 종촌동   683   0  가재마을2단지(호반베르디움3차)   59.8652
# 2      201701    2       세종특별자치시 고운동  1393   0    가락마을15단지(중흥파크뷰)   84.9894
# 3      201701    2       세종특별자치시 고운동  1706   0    가락마을8단지(고운뜰아파트)   84.9800
# 4      201701    2       세종특별자치시 아름동  1284   0    범지기마을7단지 호반에코시티   84.9280
# ...       ...  ...               ...   ...  ..                ...       ...
# 21135  202010   27  세종특별자치시 조치원읍 신흥리   399   0    조치원 신흥 e편한세상(아)  176.3430
# 21136  202010   27  세종특별자치시 조치원읍 침산리    89   0              욱일아파트   84.9900
# 21137  202010   28       세종특별자치시 도담동   639   0    도램마을17단지(모아미래도)   84.9690
# 21138  202010   28   세종특별자치시 부강면 부강리   401  48                 주연   59.8200
# 21139  202010   28  세종특별자치시 조치원읍 죽림리   396   0            조치원죽림자이   84.6641
#
#        거래금액(만원)   층  건축년도
# 0          8600   7  2016
# 1         27300   7  2014
# 2         32000   3  2015
# 3         30500  20  2015
# 4         31300   6  2014
# ...         ...  ..   ...
# 21135     50000  10  2008
# 21136     23500  20  1996
# 21137     68000   9  2015
# 21138      6500  11  1992
# 21139     37000   6  2008
#
# [21140 rows x 10 columns]

# %%
lst = df['지역명'].str.split(' ')
lst_len = lst.str.len()
df['lst_len'] = lst_len

# %%
df['lst_len'].value_counts()
# Out:
# 2    16519
# 3     4621
# Name: lst_len, dtype: int64

# %%
df
# Out:
#          계약년월  계약일               지역명    본번  부번                단지명   전용면적(㎡)  \
# 0      201701    1       세종특별자치시 보람동   628   2       스타힐타워Ⅰ(C2-3)   16.9849
# 1      201701    1       세종특별자치시 종촌동   683   0  가재마을2단지(호반베르디움3차)   59.8652
# 2      201701    2       세종특별자치시 고운동  1393   0    가락마을15단지(중흥파크뷰)   84.9894
# 3      201701    2       세종특별자치시 고운동  1706   0    가락마을8단지(고운뜰아파트)   84.9800
# 4      201701    2       세종특별자치시 아름동  1284   0    범지기마을7단지 호반에코시티   84.9280
# ...       ...  ...               ...   ...  ..                ...       ...
# 21135  202010   27  세종특별자치시 조치원읍 신흥리   399   0    조치원 신흥 e편한세상(아)  176.3430
# 21136  202010   27  세종특별자치시 조치원읍 침산리    89   0              욱일아파트   84.9900
# 21137  202010   28       세종특별자치시 도담동   639   0    도램마을17단지(모아미래도)   84.9690
# 21138  202010   28   세종특별자치시 부강면 부강리   401  48                 주연   59.8200
# 21139  202010   28  세종특별자치시 조치원읍 죽림리   396   0            조치원죽림자이   84.6641
#
#        거래금액(만원)   층  건축년도  lst_len
# 0          8600   7  2016        2
# 1         27300   7  2014        2
# 2         32000   3  2015        2
# 3         30500  20  2015        2
# 4         31300   6  2014        2
# ...         ...  ..   ...      ...
# 21135     50000  10  2008        3
# 21136     23500  20  1996        3
# 21137     68000   9  2015        2
# 21138      6500  11  1992        3
# 21139     37000   6  2008        3
#
# [21140 rows x 11 columns]

# %%
df1 = df[df['lst_len'] == 2]
df1
# Out:
#          계약년월  계약일          지역명    본번  부번                단지명  전용면적(㎡)  \
# 0      201701    1  세종특별자치시 보람동   628   2       스타힐타워Ⅰ(C2-3)  16.9849
# 1      201701    1  세종특별자치시 종촌동   683   0  가재마을2단지(호반베르디움3차)  59.8652
# 2      201701    2  세종특별자치시 고운동  1393   0    가락마을15단지(중흥파크뷰)  84.9894
# 3      201701    2  세종특별자치시 고운동  1706   0    가락마을8단지(고운뜰아파트)  84.9800
# 4      201701    2  세종특별자치시 아름동  1284   0    범지기마을7단지 호반에코시티  84.9280
# ...       ...  ...          ...   ...  ..                ...      ...
# 21130  202010   26  세종특별자치시 도담동   681   0      도램마을4단지(이지더원)  59.9853
# 21131  202010   26  세종특별자치시 도담동   664   0         라온프라이빗시티 Ⅰ  18.3000
# 21132  202010   26  세종특별자치시 소담동  3302   6  새샘마을6단지(한신더휴펜타힐스)  59.5000
# 21134  202010   26  세종특별자치시 한솔동   940   0     첫마을2단지(퍼스트프라임)  59.8300
# 21137  202010   28  세종특별자치시 도담동   639   0    도램마을17단지(모아미래도)  84.9690
#
#        거래금액(만원)   층  건축년도  lst_len
# 0          8600   7  2016        2
# 1         27300   7  2014        2
# 2         32000   3  2015        2
# 3         30500  20  2015        2
# 4         31300   6  2014        2
# ...         ...  ..   ...      ...
# 21130     54700  16  2014        2
# 21131      7500   3  2014        2
# 21132     50000   8  2017        2
# 21134     45000   6  2011        2
# 21137     68000   9  2015        2
#
# [16519 rows x 11 columns]

# %%
df1['시군구'] = df1['지역명'].str.split(' ').str[0]
df1['동리'] = df1['지역명'].str.split(' ').str[1]
df1
# Out:
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#          계약년월  계약일          지역명    본번  부번                단지명  전용면적(㎡)  \
# 0      201701    1  세종특별자치시 보람동   628   2       스타힐타워Ⅰ(C2-3)  16.9849
# 1      201701    1  세종특별자치시 종촌동   683   0  가재마을2단지(호반베르디움3차)  59.8652
# 2      201701    2  세종특별자치시 고운동  1393   0    가락마을15단지(중흥파크뷰)  84.9894
# 3      201701    2  세종특별자치시 고운동  1706   0    가락마을8단지(고운뜰아파트)  84.9800
# 4      201701    2  세종특별자치시 아름동  1284   0    범지기마을7단지 호반에코시티  84.9280
# ...       ...  ...          ...   ...  ..                ...      ...
# 21130  202010   26  세종특별자치시 도담동   681   0      도램마을4단지(이지더원)  59.9853
# 21131  202010   26  세종특별자치시 도담동   664   0         라온프라이빗시티 Ⅰ  18.3000
# 21132  202010   26  세종특별자치시 소담동  3302   6  새샘마을6단지(한신더휴펜타힐스)  59.5000
# 21134  202010   26  세종특별자치시 한솔동   940   0     첫마을2단지(퍼스트프라임)  59.8300
# 21137  202010   28  세종특별자치시 도담동   639   0    도램마을17단지(모아미래도)  84.9690
#
#        거래금액(만원)   층  건축년도  lst_len      시군구   동리
# 0          8600   7  2016        2  세종특별자치시  보람동
# 1         27300   7  2014        2  세종특별자치시  종촌동
# 2         32000   3  2015        2  세종특별자치시  고운동
# 3         30500  20  2015        2  세종특별자치시  고운동
# 4         31300   6  2014        2  세종특별자치시  아름동
# ...         ...  ..   ...      ...      ...  ...
# 21130     54700  16  2014        2  세종특별자치시  도담동
# 21131      7500   3  2014        2  세종특별자치시  도담동
# 21132     50000   8  2017        2  세종특별자치시  소담동
# 21134     45000   6  2011        2  세종특별자치시  한솔동
# 21137     68000   9  2015        2  세종특별자치시  도담동
#
# [16519 rows x 13 columns]

# %%
df2 = df[df['lst_len'] == 3]
df2
# Out:
#          계약년월  계약일               지역명   본번  부번              단지명   전용면적(㎡)  \
# 6      201701    2   세종특별자치시 연서면 봉암리  622   0           대원네스트빌   59.8580
# 7      201701    2  세종특별자치시 조치원읍 신안리  542   0          세종e편한세상   84.7067
# 8      201701    2  세종특별자치시 조치원읍 신흥리  398   0         신흥대우푸르지오   84.9228
# 9      201701    2  세종특별자치시 조치원읍 죽림리  396   0          조치원죽림자이   84.6682
# 10     201701    2  세종특별자치시 조치원읍 죽림리  396   0          조치원죽림자이  128.9491
# ...       ...  ...               ...  ...  ..              ...       ...
# 21133  202010   26  세종특별자치시 조치원읍 번암리   75   2             번암주공   46.6800
# 21135  202010   27  세종특별자치시 조치원읍 신흥리  399   0  조치원 신흥 e편한세상(아)  176.3430
# 21136  202010   27  세종특별자치시 조치원읍 침산리   89   0            욱일아파트   84.9900
# 21138  202010   28   세종특별자치시 부강면 부강리  401  48               주연   59.8200
# 21139  202010   28  세종특별자치시 조치원읍 죽림리  396   0          조치원죽림자이   84.6641
#
#        거래금액(만원)   층  건축년도  lst_len
# 6          9400   5  2002        3
# 7         19000  11  2013        3
# 8         13000   8  2006        3
# 9         19850   4  2008        3
# 10        22500   8  2008        3
# ...         ...  ..   ...      ...
# 21133     14200   4  1989        3
# 21135     50000  10  2008        3
# 21136     23500  20  1996        3
# 21138      6500  11  1992        3
# 21139     37000   6  2008        3
#
# [4621 rows x 11 columns]

# %%
df2['시군구'] = df2['지역명'].str.split(' ').str[0]
df2['읍면동'] = df2['지역명'].str.split(' ').str[1]
df2['동리'] = df2['지역명'].str.split(' ').str[2]
df2
# Out:
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /opt/app-root/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#          계약년월  계약일               지역명   본번  부번              단지명   전용면적(㎡)  \
# 6      201701    2   세종특별자치시 연서면 봉암리  622   0           대원네스트빌   59.8580
# 7      201701    2  세종특별자치시 조치원읍 신안리  542   0          세종e편한세상   84.7067
# 8      201701    2  세종특별자치시 조치원읍 신흥리  398   0         신흥대우푸르지오   84.9228
# 9      201701    2  세종특별자치시 조치원읍 죽림리  396   0          조치원죽림자이   84.6682
# 10     201701    2  세종특별자치시 조치원읍 죽림리  396   0          조치원죽림자이  128.9491
# ...       ...  ...               ...  ...  ..              ...       ...
# 21133  202010   26  세종특별자치시 조치원읍 번암리   75   2             번암주공   46.6800
# 21135  202010   27  세종특별자치시 조치원읍 신흥리  399   0  조치원 신흥 e편한세상(아)  176.3430
# 21136  202010   27  세종특별자치시 조치원읍 침산리   89   0            욱일아파트   84.9900
# 21138  202010   28   세종특별자치시 부강면 부강리  401  48               주연   59.8200
# 21139  202010   28  세종특별자치시 조치원읍 죽림리  396   0          조치원죽림자이   84.6641
#
#        거래금액(만원)   층  건축년도  lst_len      시군구   읍면동   동리
# 6          9400   5  2002        3  세종특별자치시   연서면  봉암리
# 7         19000  11  2013        3  세종특별자치시  조치원읍  신안리
# 8         13000   8  2006        3  세종특별자치시  조치원읍  신흥리
# 9         19850   4  2008        3  세종특별자치시  조치원읍  죽림리
# 10        22500   8  2008        3  세종특별자치시  조치원읍  죽림리
# ...         ...  ..   ...      ...      ...   ...  ...
# 21133     14200   4  1989        3  세종특별자치시  조치원읍  번암리
# 21135     50000  10  2008        3  세종특별자치시  조치원읍  신흥리
# 21136     23500  20  1996        3  세종특별자치시  조치원읍  침산리
# 21138      6500  11  1992        3  세종특별자치시   부강면  부강리
# 21139     37000   6  2008        3  세종특별자치시  조치원읍  죽림리
#
# [4621 rows x 14 columns]

# %%
del df1['lst_len']
del df2['lst_len']

# %%
final_df = pd.concat([df1, df2])
final_df
# Out:
#          계약년월  계약일               지역명    본번  부번                단지명   전용면적(㎡)  \
# 0      201701    1       세종특별자치시 보람동   628   2       스타힐타워Ⅰ(C2-3)   16.9849
# 1      201701    1       세종특별자치시 종촌동   683   0  가재마을2단지(호반베르디움3차)   59.8652
# 2      201701    2       세종특별자치시 고운동  1393   0    가락마을15단지(중흥파크뷰)   84.9894
# 3      201701    2       세종특별자치시 고운동  1706   0    가락마을8단지(고운뜰아파트)   84.9800
# 4      201701    2       세종특별자치시 아름동  1284   0    범지기마을7단지 호반에코시티   84.9280
# ...       ...  ...               ...   ...  ..                ...       ...
# 21133  202010   26  세종특별자치시 조치원읍 번암리    75   2               번암주공   46.6800
# 21135  202010   27  세종특별자치시 조치원읍 신흥리   399   0    조치원 신흥 e편한세상(아)  176.3430
# 21136  202010   27  세종특별자치시 조치원읍 침산리    89   0              욱일아파트   84.9900
# 21138  202010   28   세종특별자치시 부강면 부강리   401  48                 주연   59.8200
# 21139  202010   28  세종특별자치시 조치원읍 죽림리   396   0            조치원죽림자이   84.6641
#
#        거래금액(만원)   층  건축년도      시군구   동리   읍면동
# 0          8600   7  2016  세종특별자치시  보람동   NaN
# 1         27300   7  2014  세종특별자치시  종촌동   NaN
# 2         32000   3  2015  세종특별자치시  고운동   NaN
# 3         30500  20  2015  세종특별자치시  고운동   NaN
# 4         31300   6  2014  세종특별자치시  아름동   NaN
# ...         ...  ..   ...      ...  ...   ...
# 21133     14200   4  1989  세종특별자치시  번암리  조치원읍
# 21135     50000  10  2008  세종특별자치시  신흥리  조치원읍
# 21136     23500  20  1996  세종특별자치시  침산리  조치원읍
# 21138      6500  11  1992  세종특별자치시  부강리   부강면
# 21139     37000   6  2008  세종특별자치시  죽림리  조치원읍
#
# [21140 rows x 13 columns]

# %%
final_df.to_csv('3.아파트_split.csv', index = False, encoding = 'utf-8')
